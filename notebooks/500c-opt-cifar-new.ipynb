# %%
import comet_ml
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
comet_api = comet_ml.api.API()

# %%
exps = comet_api.get('federated-learning/500c-opt-cifar-new')

# %%
lrs = [float(exp.get_parameters_summary('LEARNING_RATE')['valueMax']) for exp in exps]
teas = [float(exp.get_metrics_summary('test_acc')['valueMax']) for exp in exps]
opts = [exp.get_parameters_summary('OPT')['valueMax'] for exp in exps]
opt_strats = [exp.get_parameters_summary('OPT_STRATEGY')['valueMax'] for exp in exps]
ids = [exp.id for exp in exps]

# %%
df = pd.DataFrame({'id': ids, 'lr': lrs, 'test_acc': teas, 'opt': opts, 'opt_str': opt_strats})
# df_fin = df[df['test_acc'] > 99]
# [float(d['metricValue']) for d in exp.get_metrics('test_acc')]

# %%
df.iloc[df.groupby(['opt', 'opt_str']).idxmax()['test_acc']]
# Out:
#                                    id      lr  test_acc       opt  opt_str
# 6    77d5367536b449198dd4f3934988afac  0.1000     13.58      ASGD      avg
# 23   f2738be511b3466cbfeb760a68e2a130  0.1000     14.60      ASGD  nothing
# 19   a8cad24bab474a22963fd3f580f7aca3  0.1000     14.01      ASGD   reinit
# 63   0baabf993d624f638fc0741a63a30096  1.0000     21.16  Adadelta      avg
# 71   564578ac55804a20b635a31f1f94db51  1.0000     17.68  Adadelta  nothing
# 67   0c407d9c67d64dcf9efa3a2fd43cbccc  1.0000     17.55  Adadelta   reinit
# 105  5db1721c2b9a48178075cad0b35ccf94  0.0100     20.62   Adagrad      avg
# 122  146021b6cc82487b980f4a25476b96e3  0.0010     17.63   Adagrad   reinit
# 38   b945ff4fc9e84f56b88b96607b09227a  0.0010     20.25      Adam      avg
# 46   87081dabb1ed45f4a205135629c3be8a  0.0010     17.42      Adam  nothing
# 42   48d20f08dfae4d1c89f954cacf69ab70  0.0010     18.39      Adam   reinit
# 114  88d6b95242a24a12993d0901bb8584d2  0.0010     20.26     AdamW      avg
# 119  c2d9474b70af42f3ba8f5f6b6eec7bab  0.0010     16.20     AdamW   reinit
# 100  239912f83dd74e10a936f6f16a329c1f  0.0100     18.68    Adamax      avg
# 129  4518bb9688824cbbae363ecb993bfe31  0.0001      6.95    Adamax   reinit
# 116  985d50092b504d21a59ac19c5e8e6eff  0.0010     20.72   RMSprop      avg
# 133  e12d25cef4344cb780609652f2e2d752  0.0001     18.58   RMSprop   reinit
# 126  3b9ce6e9ad044e299180012b078dd0af  0.0001      2.38     Rprop      avg
# 120  e098f5e7ac2549e6b7d96daeb38334b6  0.0010     16.44     Rprop   reinit
# 8    280b4026a9794873973d746d9589153f  0.1000     14.46       SGD      avg
# 25   25adc312d2eb4733b0ad959560a9cb7e  0.1000     13.12       SGD  nothing
# 95   822877f6929c43328cad77cf36a2a501  0.1000     14.57       SGD   reinit
