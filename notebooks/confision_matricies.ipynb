# %%
import matplotlib.pyplot as plt
import comet_ml
comet_api = comet_ml.api.API()

# %%
exp = comet_api.get('federated-learning/server-yogi-l2/331206750ff745959fb927ef5de626f7')

# %%
cmas = exp.get_asset_list()

# %%
for d in cmas:
    if d['step'] == 1499 and d['type'] == 'confusion-matrix':
        cm = exp.get_asset(d['assetId'], return_type='json')
        break

# %%
{k:type(v) for k, v in cm.items()}
# Out:
# {'version': int,
#  'title': str,
#  'labels': list,
#  'matrix': list,
#  'rowLabel': str,
#  'columnLabel': str,
#  'maxSamplesPerCell': int,
#  'sampleMatrix': NoneType,
#  'type': NoneType}

# %%
{k: np.array(cm[k]).shape for k in ['labels', 'matrix', 'rowLabel']}
# Out:
# {'labels': (100,), 'matrix': (100, 100), 'rowLabel': ()}

# %%
plt.plot(np.array(cm['matrix']).sum(axis=0))
